# %%
from postgres_connect import *
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
path = 'tunnel-ssh.cer'
# printthis('yes')
conn = get_conn('Yes',path)
# Out:
# Tunnel Started
# Connection Made

# %%
query = '''
select 
    shipping_city
,   hub
,   rider_id
,   rider_name
,   need_improvement
,   starting_fasr
from public.rider_pip
where pip_date = '2023-12-18'
'''

# %%
df_pip = pd.read_sql(query,conn)

# %%
df_pip
# Out:
#    shipping_city          hub                        rider_id  \
# 0      Bangalore  DS BLR BOMM                  Shashank_Rao_2
# 1      Bangalore  DS BLR BOMM                 Pavan_Kumar_R_2
# 2      Bangalore  DS BLR HBBL                       Kiram_P_7
# 3      Bangalore   DS BLR MTH     DILIP_KUMAR_TATA_ACE_MRTH_1
# 4          Delhi   DS DEL DWK  Amar_Kumar_Singh__5_1700989242
# 5          Delhi   DS DEL DWK          Ankit_JPS_5_1700892680
# 6          Delhi   DS DEL DWK          Himanshu_Singh_Laksh_5
# 7          Delhi   DS DEL DWK             Anuj_kumar_pandey_5
# 8          Delhi   DS DEL DWK    Ravi_Ranjan_JPS_5_1700813523
# 9          Delhi   DS DEL DWK                   Rahul_Laksh_5
# 10         Delhi   DS DEL DWK   MD_wasim_Khan_Ps_5_1701326560
# 11         Delhi   DS DEL DWK          subham_saxena_van_de_5
# 12         Delhi   DS DEL DWK          Sagar_Ps1_5_1701072680
# 13         Delhi   DS DEL DWK              Sagar_sharma_JPS_5
# 14         Delhi   DS DEL DWK    Kamal_Singh_JPS_5_1701160867
# 15         Delhi   DS DEL DWK                     Rahul_JPS_5
# 16         Delhi   DS DEL DWK              Anirudh_Singh_GS_5
# 17         Delhi   DS DEL DWK       DS_NCT_DWRK_0105202315_11
# 18         Delhi   DS DEL DWK            Subhash_chander_PS_5
# 19         Delhi   DS DEL DWK                     Ak_Rajish_5
# 20         Delhi   DS DEL DWK        DS_NCT_DWRK_28032022_100
# 21         Delhi   DS DEL DWK         DS_NCT_DWRK_28032022_24
# 22         Delhi   DS DEL DWK                    Rajeev_VLS_5
# 23         Delhi   DS DEL DWK                  Ankit_Kumar__5
# 24         Delhi  DS DEL RNGR                faizan_rahman_21
# 25         Delhi  DS DEL RNGR              Deepak_kumar_PS_21
# 26         Delhi  DS DEL RNGR             Krishan_Kumar_PS_21
# 27     Hyderabad   DS HYD KMP          RAVIKANT__4_1701242716
# 28     Hyderabad   DS HYD KMP                      U_Naresh_4
# 29     Hyderabad  DS HYD SRNG               Pudari_Ramesh__19
# 30        Mumbai   DS BOM KRL        DS_BOM_KRL_24082022_0001
# 31        Mumbai   DS BOM KRL         Yahya_Iqtedar_husain__3
# 32        Mumbai   DS BOM KRL           mohd_Shahnawaz_shah_3
# 33        Mumbai   DS BOM KRL         Kiran_Mane_3_1701335538
# 34        Mumbai   DS BOM KRL       imran_shaikh_3_1701336244
# 35        Mumbai   DS BOM KRL                 Rehan_Sakware_3
# 36        Mumbai   DS BOM KRL             Taj_Mohammed_Khan_3
# 37        Mumbai   DS BOM KRL            Siddharth_b_savadh_3
# 38        Mumbai   DS BOM KRL            Masuldar_Alauddin__3
# 39        Mumbai   DS BOM KRL         manjur_Kasam_qureshi_17
# 40         Delhi   DS DEL DWK              Neeraj_Baghel_PS_5
# 41         Delhi   DS DEL DWK                  Lucky_Laksh__5
# 42         Delhi   DS DEL DWK    Vikram_Rapydex__5_1701249394
# 43         Delhi   DS DEL DWK              Devesh_Kumar_VLS_5
# 44         Delhi   DS DEL DWK           pankit_kumar_van_de_5
# 45         Delhi  DS DEL HKMN                   Pawan_Kumar_5
# 46         Delhi  DS DEL RNGR                Amit_yadav_PS_21
# 47         Delhi  DS DEL RNGR    Pradeep_pal_PS_21_1701169455
# 48        Mumbai   DS BOM KRL               Saif_Khanderiya_3
# 49        Mumbai   DS BOM KRL     arshad_Shaikh__3_1701335934
# 50        Mumbai  DS BOM SWRI            arif_abdullah_kazi_3
#
#                    rider_name  \
# 0                Shashank Rao
# 1               Pavan Kumar R
# 2                     Kiram P
# 3   DILIP KUMAR TATA ACE MRTH
# 4        Amar Kumar Singh JPS
# 5                   Ankit JPS
# 6        Himanshu Singh Laksh
# 7       Anuj kumar pandey jps
# 8             Ravi Ranjan JPS
# 9                 Rahul Laksh
# 10           MD wasim Khan Ps
# 11       subham saxena van de
# 12                  Sagar Ps1
# 13           Sagar sharma JPS
# 14            Kamal Singh JPS
# 15                  Rahul JPS
# 16           Anirudh Singh GS
# 17              Rohit Kashyap
# 18         Subhash chander PS
# 19                  Ak Rajish
# 20            Amardeep Bhagat
# 21               Himanshu Pal
# 22                 Rajeev JPS
# 23               Ankit Kumar
# 24              faizan rahman
# 25            Deepak kumar PS
# 26           Krishan Kumar PS
# 27                  RAVIKANT
# 28                   U Naresh
# 29             Pudari Ramesh
# 30                Sunil Gadge
# 31      Yahya Iqtedar husain
# 32        mohd Shahnawaz shah
# 33                 Kiran Mane
# 34               imran shaikh
# 35              Rehan Sakware
# 36          Taj Mohammed Khan
# 37         Siddharth b savadh
# 38         Masuldar Alauddin
# 39       manjur Kasam qureshi
# 40           Neeraj Baghel PS
# 41               Lucky Laksh
# 42            Vikram Rapydex
# 43           Devesh Kumar VLS
# 44        pankit kumar van de
# 45                Pawan Kumar
# 46              Amit yadav PS
# 47             Pradeep pal PS
# 48            Saif Khanderiya
# 49             arshad Shaikh
# 50         arif abdullah kazi
#
#                                      need_improvement  starting_fasr
# 0        Morning Prepaid (60%) Morning Prepaid (17%)            50.0
# 1   Morning Prepaid (83%) Morning COD(33%) Morning...           64.0
# 2                                   Morning COD(57%)            81.0
# 3             Morning Prepaid (80%) Morning COD(50%)            79.0
# 4   Morning Prepaid (53%) Morning COD(12%) Morning...           41.0
# 5   Morning Prepaid (50%) Morning COD(50%) Morning...           53.0
# 6        Morning Prepaid (73%) Morning Prepaid (25%)            56.0
# 7   Morning COD(40%) Morning Prepaid (75%) Morning...           57.0
# 8   Morning Prepaid (75%) Morning COD(22%) Morning...           58.0
# 9                              Morning Prepaid (72%)            60.0
# 10       Morning Prepaid (75%) Morning Prepaid (48%)            61.0
# 11                             Morning Prepaid (59%)            61.0
# 12       Morning Prepaid (76%) Morning Prepaid (49%)            62.0
# 13            Morning COD(50%) Morning Prepaid (67%)            62.0
# 14            Morning Prepaid (83%) Morning COD(42%)            72.0
# 15       Morning Prepaid (83%) Morning Prepaid (43%)            73.0
# 16       Morning Prepaid (41%) Morning Prepaid (12%)            73.0
# 17  Morning COD(48%) Morning Prepaid (78%) Morning...           74.0
# 18                                  Morning COD(57%)            75.0
# 19                             Morning Prepaid (29%)            75.0
# 20                                  Morning COD(53%)            75.0
# 21                                  Morning COD(55%)            76.0
# 22                                  Morning COD(59%)            77.0
# 23                             Morning Prepaid (83%)            79.0
# 24            Morning Prepaid (33%) Morning COD(35%)            34.0
# 25       Morning Prepaid (75%) Morning Prepaid (39%)            60.0
# 26                                  Morning COD(48%)            76.0
# 27                                  Morning COD(49%)            77.0
# 28                             Morning Prepaid (85%)            78.0
# 29  Morning Prepaid (69%) Morning COD(50%) Morning...           63.0
# 30       Morning Prepaid (50%) Morning Prepaid (25%)            41.0
# 31       Morning Prepaid (49%) Morning Prepaid (33%)            43.0
# 32       Morning Prepaid (63%) Morning Prepaid (29%)            51.0
# 33            Morning Prepaid (67%) Morning COD(38%)            54.0
# 34       Morning Prepaid (68%) Morning Prepaid (38%)            59.0
# 35  Morning Prepaid (65%) Morning COD(38%) Morning...           66.0
# 36       Morning Prepaid (76%) Morning Prepaid (32%)            66.0
# 37        Morning Prepaid (72%) Morning Prepaid (0%)            73.0
# 38  Morning COD(50%) Morning Prepaid (60%) Morning...           80.0
# 39                                  Morning COD(56%)            81.0
# 40       Morning Prepaid (77%) Morning Prepaid (36%)            66.0
# 41       Morning Prepaid (80%) Morning Prepaid (70%)            69.0
# 42                             Morning Prepaid (44%)            71.0
# 43                                  Morning COD(50%)            77.0
# 44                             Morning Prepaid (80%)            81.0
# 45            Morning COD(56%) Morning Prepaid (25%)            82.0
# 46       Morning Prepaid (69%) Morning Prepaid (37%)            53.0
# 47            Morning COD(52%) Morning Prepaid (43%)            80.0
# 48            Morning Prepaid (71%) Morning COD(31%)            61.0
# 49                             Morning Prepaid (79%)            71.0
# 50            Morning Prepaid (84%) Morning COD(50%)            81.0
